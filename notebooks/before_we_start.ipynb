# %% [markdown]
# # Welcome to your Machine Learning Bootcamp!

# %% [markdown]
# ## Upon completion of this workshop, you will be familiar with:
# * Jupyter Notebooks
# * Python's scientific computing ecosystem
# * Various machine learning algorithms commonly used in production
# * Docker / Docker-Compose
# * Flask-Restful - a Python RESTful api server

# %% [markdown]
# ## Digitalist specific goals:
# **1) Build a solid foundation of ML fundamentals so that we can advance our ML expertise within the company.**
# **2) Gain the ability to better recognize ML/AI opportunities for new and existing clients  **
#
# If anyone has more specific goals, please tell!

# %% [markdown]
# ## Some Machine Learning discussion before we start

# %%
from IPython.display import Image

# %% [markdown]
# ## What do we mean by...

# %% [markdown]
# ### Supervised vs. Unsupervised Learning?
# ### Classification vs. Regression?

# %%
Image('./images/machinelearningtypes.jpg')

# %%
Image('./images/classification-vs-regression.png')

# %% [markdown]
# ## The general ML workflow
# We will be implementing this very pipeline today!

# %%
Image('./images/ML_flowchart.png')

# %% [markdown]
# ## Some cheatsheets:

# %%
Image('./images/machine-learning-cheet-sheet.png')

# %%
Image('./images/ML_paradigms.png')
